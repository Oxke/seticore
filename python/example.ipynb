# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install h5py
# Out:
# Collecting h5py
#   Downloading h5py-3.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy>=1.19.3 in /home/obs/.conda/envs/osea/lib/python3.10/site-packages (from h5py) (2.2.6)
# Downloading h5py-3.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 32.0 MB/s eta 0:00:00
# Installing collected packages: h5py
# Successfully installed h5py-3.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pwd
# Out:
# '/datax/users/obs/osea/seticore/python'

# %%
import viewer
import numpy as np

# %%
events = list(viewer.read_events("../data/voyager.hits"))

# %%
for h in events[0].hits: viewer.show_hit(h)
# Out:
# ---------------------------------------------------------------------------
# KjException                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 for h in events[0].hits: viewer.show_hit(h)
#
# File ~/.conda/envs/osea/lib/python3.10/site-packages/capnp/lib/capnp.pyx:1159, in capnp.lib.capnp._DynamicStructReader.__getattr__()
#
# File ~/.conda/envs/osea/lib/python3.10/site-packages/capnp/lib/capnp.pyx:1157, in capnp.lib.capnp._DynamicStructReader.__getattr__()
#
# File ~/.conda/envs/osea/lib/python3.10/site-packages/capnp/lib/capnp.pyx:1153, in capnp.lib.capnp._DynamicStructReader._get()
#
# KjException: capnp/layout.c++:2289: failed: expected ref->kind() == WirePointer::LIST [0 == 1]; Schema mismatch: Message contains non-list pointer where list pointer was expected.
# stack: 7f16fd6ce61a 7f16fd70845e 7f16fd708faf 7f16fd59c133 7f16fd567d3b 55dc49d5c151 55dc49d53819 55dc49def3bb 55dc49def306 55dc49df655a 55dc49d5f2b2 55dc49d4f3bb 55dc49df8c38 55dc49d50c11 55dc49df8c38 55dc49d50c11 55dc49df8c38 55dc49e0d066 55dc49d6948c 55dc49d4f7af 55dc49d5f0eb 55dc49d4f3bb 55dc49d5f0eb 55dc49d4f7af 55dc49d6a4b1 55dc49d6ae4b 55dc49d51c54 55dc49d6a4b1 55dc49d503ef 55dc49df8c38 55dc49d50c11

# %%
for h in events[1].hits: viewer.show_hit(h)
# Out:
# ---------------------------------------------------------------------------
# KjException                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 for h in events[1].hits: viewer.show_hit(h)
#
# File ~/.conda/envs/osea/lib/python3.10/site-packages/capnp/lib/capnp.pyx:1159, in capnp.lib.capnp._DynamicStructReader.__getattr__()
#
# File ~/.conda/envs/osea/lib/python3.10/site-packages/capnp/lib/capnp.pyx:1157, in capnp.lib.capnp._DynamicStructReader.__getattr__()
#
# File ~/.conda/envs/osea/lib/python3.10/site-packages/capnp/lib/capnp.pyx:1153, in capnp.lib.capnp._DynamicStructReader._get()
#
# KjException: capnp/layout.c++:2289: failed: expected ref->kind() == WirePointer::LIST [0 == 1]; Schema mismatch: Message contains non-list pointer where list pointer was expected.
# stack: 7f16fd6ce61a 7f16fd70845e 7f16fd708faf 7f16fd59c133 7f16fd567d3b 55dc49d5c151 55dc49d53819 55dc49def3bb 55dc49def306 55dc49df655a 55dc49d5f2b2 55dc49d4f3bb 55dc49df8c38 55dc49d50c11 55dc49df8c38 55dc49d50c11 55dc49df8c38 55dc49e0d066 55dc49d6948c 55dc49d4f7af 55dc49d5f0eb 55dc49d4f3bb 55dc49d5f0eb 55dc49d4f7af 55dc49d6a4b1 55dc49d6ae4b 55dc49d51c54 55dc49d6a4b1 55dc49d503ef 55dc49df8c38 55dc49d50c11

# %%
for h in events[2].hits: viewer.show_hit(h)
# Out:
# hit with source VOYAGER-1, incoherent beam, 8419.52040 MHz, 22.6 SNR, -0.367 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 8419.51983 MHz, 10.5 SNR, -0.378 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 8419.51990 MHz, 19.0 SNR, -0.418 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:
